# %%
import cv2
import numpy as np

np.unique(cv2.imread('/mnt/data/omkumar/foundation_phase1/datasets/IDRiD/masks/IDRiD_01.png',cv2.IMREAD_GRAYSCALE))
# Out:
# array([0, 1, 2, 3, 4], dtype=uint8)

# %%
import cv2

cv2.imread('/mnt/data/omkumar/foundation_phase1/datasets/Cataracts/images/0000000000_rgb_mask.png').shape
# Out:
# (360, 640, 3)
