# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('/home/asavari/foundation_model/datasets/Cataract/masks_final/0000000000_rgb_mask.png')
# Out:
# (299, 299, 3)

# %%
import cv2
import numpy as np

np.unique(cv2.imread('/home/asavari/foundation_model/datasets/Cataract/masks_final/0000000000_rgb_mask.png'))
# Out:
# array([0, 1, 2], dtype=uint8)
