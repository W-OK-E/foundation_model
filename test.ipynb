# %%
import pickle

with open('/home/asavari/ablations/IDRID-HRDecoder/Out/results.pkl') as file:
    data = pickle.load(file)

# %%
met = {"class_0_iou": 0.0, "class_0_f": 0.0, "class_0_precision": 0.0, "class_0_recall": 0.0, "class_1_iou": 60.297584533691406, "class_1_f": 75.2320556640625, "class_1_precision": 64.83121490478516, "class_1_recall": 89.60779571533203, "class_2_iou": 77.40060424804688, "class_2_f": 87.26081085205078, "class_2_precision": 83.437255859375, "class_2_recall": 91.4516372680664, "class_3_iou": 0.061081767082214355, "class_3_f": 0.1220889613032341, "class_3_precision": 29.878049850463867, "class_3_recall": 0.06116946041584015, "class_4_iou": 67.5657958984375, "class_4_f": 80.6438980102539, "class_4_precision": 99.24921417236328, "class_4_recall": 67.91290283203125, "class_5_iou": 19.435678482055664, "class_5_f": 32.54584884643555, "class_5_precision": 25.10090446472168, "class_5_recall": 46.26938247680664}

mean = []
for k,v in met.items():
    mean.append(v)

print(sum(mean)/len(mean))

# %%
import torch
import torch.nn as nn

text_embed = torch.randn(4,512)
text_proj = nn.Linear(512,758)

# %%
text_proj(text_embed)
# Out:
# tensor([[ 0.7156,  1.1713,  0.1347,  ...,  0.2716, -0.2988,  0.1484],
#         [-0.5737, -0.3964, -0.9830,  ...,  0.1403, -0.3177,  0.4238],
#         [ 1.4295, -0.0274,  0.6458,  ..., -0.0580,  0.2740,  0.7091],
#         [ 0.5267, -0.8699,  0.5905,  ...,  0.2632,  0.6182,  0.6919]],
#        grad_fn=<AddmmBackward0>)

# %%
lst = ["pupil", "cornea", "skin", "iris", "surgical_instrument", "hand", "speculum", "other_instruments", "lens", "background", "misc"]
len(lst)
# Out:
# 11

# %%
lst.extend(["misc"]*25)

# %%
print(lst)
# Out:
# ['pupil', 'cornea', 'skin', 'iris', 'surgical_instrument', 'hand', 'speculum', 'other_instruments', 'lens', 'background', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc', 'misc']
